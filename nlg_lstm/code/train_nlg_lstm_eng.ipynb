# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import pickle
import random

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

import os

# %% [markdown]
# # Load Dataset

# %%
# _PROJECT_PATH = '/content/drive/MyDrive/Colab Notebooks/nlg'
_PROJECT_PATH = '/home/taindp/VINBRAIN_INTERNSHIP/nlg_lstm'

# %%
# %pwd

# %%
# read pickle file
pickle_in = open(os.path.join(_PROJECT_PATH,"data/plots_text.pickle"),"rb")
movie_plots = pickle.load(pickle_in)

# count of movie plot summaries
len(movie_plots)
# Out:
# 500

# %% [markdown]
# # Data Preparation

# %%
# clean text
movie_plots = [re.sub("[^a-z' ]", "", i) for i in movie_plots]

# %%
movie_plots
# Out:
# ["barry is a private with the st airborne division of the united states army stationed at fort campbell kentucky calpernia works as a showgirl at a transgender revue in nashville tennessee when the two met in  barry's roommate justin fisher  brings barry to the club where she performs when barry and calpernia begin seeing each other regularly fisher begins spreading rumors on base about their relationship which appeared to be a violation of the military's don't ask don't tell policy about discussing the sexual orientation of military personnel barry faces increasing harassment and pressure which explode into violence over fourth of july weekend while calpernia performs in a pageant in nashville barry is beaten to death in his sleep with a baseball bat by calvin glover who had been goaded by fisher into committing the crime the film ends with a discussion of the aftermath",
#  'chinese exorcist oneeyebrow priest  leads a peaceful life with two disciples ah hao  and ah fang  in a small town together with a naughty mini vampire while finding new water sources one day the priest encounters a european vampire in the nearby church who is aided by a dead countess although the priest manages to get rid of the countess his chinese exorcism fails on the european vampire',
#  "while playing baseball on a busy street in greenpoint mickey is struck by a car though he fully recovers from his injuries mickey meets several other kids in the hospital who weren't so lucky instantly developing a sense of civic responsibility the gang members establish the  go safety society dedicated to lowering the number of auto injuries in their communityref namehttpmoviesnytimescommoviegooverview titleworkny times",
#  "thadeous and fabious danny mcbride  are sons of king tallious  they are warriors fabious is dashing and skilled and thadeous is lazy and ineffectual while celebrating his latest victory over the evil sorcerer who has been ravaging tallious's kingdom leezar  fabious introduces the virgin belladonna  he freed from a tower and wishes to marry her though he is made the best man thadeous skips the wedding after overhearing fabious's knights elite led by boremont  talk about him negatively but the wedding is then crashed by leezar revealing himself to be the one who placed belladona in the tower before spiriting her away returning to the castle with his servant courtney  thadeous is forced into joining fabious on his quest to rescue belladonna visiting the great wise wizard thadeous and fabious learn that leezar is attempting to fulfill a prophecy of a warlock having sex with a maiden when the two moons converge impregnating her with a dragon that will allow him to take over king tallious' kingdom to destroy leezar they are given a magic compass that would lead them to the blade of unicorn located within a labyrinth on the way there they learn fabious's slave julie  has been reporting to leezar of their progress and the knights elite are serving the warlock after his brother sends his mechanical bird simon to tell the king of the betrayal by the knights elite and request reinforcements thadeous fabious and courtney are captured by nymphs under their leader marteetee  who imprisons them at an arena where fabious kills off marteetee's finest warrior in retaliation marteetee summons his hydralike familiar to kill them thadeous and fabious are rescued by isabel  a warrior seeking revenge for her father's murder at marteetee's hands later that night thadeous learns that isabel is also after leezar for the slaughter of her brothers the next day the party learn too late that isabel stole the compass from thadeous fabious decides to find the blade of unicorn alone as thadeous and courtney go to a tavern where they find isabel and steal the compass back but finding that his brother has been captured by leezar's men thadeous wins isabel over as they join forces entering the labyrinth where they
#  'when the existence of a strain of plague  is revealed at the us mission at the international health organization three terrorists seek to blow up the us mission two of them are shot one mortally by security personnel but one escapes the surviving terrorist is hospitalized and quarantined and identified as swedish dr elena stradner  and us colonel stephen mackenzie   argue over the nature of the strain which stradner suspects is a biological weapon but which colonel mackenzie claims was in the process of being destroyed the third terrorist escapes and stows away on a transcontinental train bound from geneva to stockholm dr stradner believes that the train should be stopped so that the terrorist can be removed and quarantined but col mackenzie is concerned that all of the passengers on the train may have been infected mackenzie insists on rerouting the train to an abandoned exnazi railroad line to a quarantine camp in janov poland however the line crosses a dangerously unsound steel arch bridge known as the kaslindrliv bridge or cassandra crossing out of use since  mackenzie understands that the bridge might collapse as the train passes over it the presence of the infected terrorist and the rerouting of the train precipitates the second conflict among passengers on the train they include dr jonathan chamberlain  a famous neurologist his exwife jennifer rispoli chamberlain  and nicole dressler  the wife of a german arms dealer she is embroiled in an affair with her young companion robby navarro navarro is a heroin trafficker being pursued by fbi agent haley who is traveling undercover as a priest mackenzie informs dr chamberlain of the presence of the stowaway who is found but attempts to remove the stowaway via a helicopter are unsuccessful because the train enters a tunnel chamberlain is also told that the plague has a  mortality rate mackenzie however informs passengers that police have received reports of anarchist bombs placed along the rail line and that the train will be rerouted to nuremberg there the train is sealed with an enclosed oxygen system and a us army medical team is placed aboard with the nowdeceased stowaway being placed in a hermeticallysealed coffin dr chamberlain learns of the risk of the cassandra crossing he also begins to suspect the disease is not as serious as originally thought few of the passengers have become infected and few of those have actually died he radios mackenzie suggesting the infected portion of the train be uncoupled and isolated but mackenzie has no intention of stopping the train if the expected cassandra crossing collapse occurs it will neatly cover the fact that the us has been harboring germ warfare agents in a neutral country passengers on the train work alone to stop the train before it reaches the cassandra crossing the passengers manage to seize the back half of the train roughly one km before the bridge and detach it hoping that with less weight the front half will cross safely but the bridge collapses killing everyone aboard the front half the back end applies the brakes and stops just before reaching the downed bridge in geneva both stradner and mackenzie depart she keeps hope of survivors while he thinks the elimination of the train means no investigations a guard on duty orders both of them be watched',
#  "a village in rural thailand is celebrating loy krathong when the festivities are disrupted by the descent of a spaceship ray beams are fired from the craft and all the village's women find they are suddenly pregnant only a few hours later the women give birth the alien offspring have the power to kill by just staring and they have an insatiable appetite for raw meat"]

# %%
len(movie_plots)
# Out:
# 500

# %%
def create_seq(text, seq_len = 5):
    
    sequences = []

    # if the number of tokens in 'text' is greater than 5
    if len(text.split()) > seq_len:
        for i in range(seq_len, len(text.split())):
            # select sequence of tokens
            seq = text.split()[i-seq_len:i+1]
            # add to the list
            sequences.append(" ".join(seq))

        return sequences

    # if the number of tokens in 'text' is less than or equal to 5
    else:
      
      return [text]

# %%
seqs = [create_seq(i) for i in movie_plots]

# merge list-of-lists into a single list
seqs = sum(seqs, [])

# count of sequences
len(seqs)
# Out:
# 152644

# %%
seqs
# Out:
# ['barry is a private with the',
#  'is a private with the st',
#  'a private with the st airborne',
#  'private with the st airborne division',
#  'with the st airborne division of',
#  'the st airborne division of the',
#  'st airborne division of the united',
#  'airborne division of the united states',
#  'division of the united states army',
#  'of the united states army stationed',
#  'the united states army stationed at',
#  'united states army stationed at fort',
#  'states army stationed at fort campbell',
#  'army stationed at fort campbell kentucky',
#  'stationed at fort campbell kentucky calpernia',
#  'at fort campbell kentucky calpernia works',
#  'fort campbell kentucky calpernia works as',
#  'campbell kentucky calpernia works as a',
#  'kentucky calpernia works as a showgirl',
#  'calpernia works as a showgirl at',
#  'works as a showgirl at a',
#  'as a showgirl at a transgender',
#  'a showgirl at a transgender revue',
#  'showgirl at a transgender revue in',
#  'at a transgender revue in nashville',
#  'a transgender revue in nashville tennessee',
#  'transgender revue in nashville tennessee when',
#  'revue in nashville tennessee when the',
#  'in nashville tennessee when the two',
#  'nashville tennessee when the two met',
#  'tennessee when the two met in',
#  "when the two met in barry's",
#  "the two met in barry's roommate",
#  "two met in barry's roommate justin",
#  "met in barry's roommate justin fisher",
#  "in barry's roommate justin fisher brings",
#  "barry's roommate justin fisher brings barry",
#  'roommate justin fisher brings barry to',
#  'justin fisher brings barry to the',
#  'fisher brings barry to the club',
#  'brings barry to the club where',
#  'barry to the club where she',
#  'to the club where she performs',
#  'the club where she performs when',
#  'club where she performs when barry',
#  'where she performs when barry and',
#  'she performs when barry and calpernia',
#  'performs when barry and calpernia begin',
#  'when barry and calpernia begin seeing',
#  'barry and calpernia begin seeing each',
#  'and calpernia begin seeing each other',
#  'calpernia begin seeing each other regularly',
#  'begin seeing each other regularly fisher',
#  'seeing each other regularly fisher begins',
#  'each other regularly fisher begins spreading',
#  'other regularly fisher begins spreading rumors',
#  'regularly fisher begins spreading rumors on',
#  'fisher begins spreading rumors on base',
#  'begins spreading rumors on base about',
#  'spreading rumors on base about their',
#  'rumors on base about their relationship',
#  'on base about their relationship which',
#  'base about their relationship which appeared',
#  'about their relationship which appeared to',
#  'their relationship which appeared to be',
#  'relationship which appeared to be a',
#  'which appeared to be a violation',
#  'appeared to be a violation of',
#  'to be a violation of the',
#  "be a violation of the military's",
#  "a violation of the military's don't",
#  "violation of the military's don't ask",
#  "of the military's don't ask don't",
#  "the military's don't ask don't tell",
#  "military's don't ask don't tell policy",
#  "don't ask don't tell policy about",
#  "ask don't tell policy about discussing",
#  "don't tell policy about discussing the",
#  'tell policy about discussing the sexual',
#  'policy about discussing the sexual orientation',
#  'about discussing the sexual orientation of',
#  'discussing the sexual orientation of military',
#  'the sexual orientation of military personnel',
#  'sexual orientation of military personnel barry',
#  'orientation of military personnel barry faces',
#  'of military personnel barry faces increasing',
#  'military personnel barry faces increasing harassment',
#  'personnel barry faces increasing harassment and',
#  'barry faces increasing harassment and pressure',
#  'faces increasing harassment and pressure which',
#  'increasing harassment and pressure which explode',
#  'harassment and pressure which explode into',
#  'and pressure which explode into violence',
#  'pressure which explode into violence over',
#  'which explode into violence over fourth',
#  'explode into violence over fourth of',
#  'into violence over fourth of july',
#  'violence over fourth of july weekend',
#  'over fourth of july weekend while',
#  'fourth of july weekend while calpernia',
#  'of july weekend while calpernia performs',
#  'july weekend while calpernia performs in',
#  'weekend while calpernia performs in a',
#  'while calpernia performs in a pageant',
#  'calpernia performs in a pageant in',
#  'performs in a pageant in nashville',
#  'in a pageant in nashville barry',
#  'a pageant in nashville barry is',
#  'pageant in nashville barry is beaten',
#  'in nashville barry is beaten to',
#  'nashville barry is beaten to death',
#  'barry is beaten to death in',
#  'is beaten to death in his',
#  'beaten to death in his sleep',
#  'to death in his sleep with',
#  'death in his sleep with a',
#  'in his sleep with a baseball',
#  'his sleep with a baseball bat',
#  'sleep with a baseball bat by',
#  'with a baseball bat by calvin',
#  'a baseball bat by calvin glover',
#  'baseball bat by calvin glover who',
#  'bat by calvin glover who had',
#  'by calvin glover who had been',
#  'calvin glover who had been goaded',
#  'glover who had been goaded by',
#  'who had been goaded by fisher',
#  'had been goaded by fisher into',
#  'been goaded by fisher into committing',
#  'goaded by fisher into committing the',
#  'by fisher into committing the crime',
#  'fisher into committing the crime the',
#  'into committing the crime the film',
#  'committing the crime the film ends',
#  'the crime the film ends with',
#  'crime the film ends with a',
#  'the film ends with a discussion',
#  'film ends with a discussion of',
#  'ends with a discussion of the',
#  'with a discussion of the aftermath',
#  'chinese exorcist oneeyebrow priest leads a',
#  'exorcist oneeyebrow priest leads a peaceful',
#  'oneeyebrow priest leads a peaceful life',
#  'priest leads a peaceful life with',
#  'leads a peaceful life with two',
#  'a peaceful life with two disciples',
#  'peaceful life with two disciples ah',
#  'life with two disciples ah hao',
#  'with two disciples ah hao and',
#  'two disciples ah hao and ah',
#  'disciples ah hao and ah fang',
#  'ah hao and ah fang in',
#  'hao and ah fang in a',
#  'and ah fang in a small',
#  'ah fang in a small town',
#  'fang in a small town together',
#  'in a small town together with',
#  'a small town together with a',
#  'small town together with a naughty',
#  'town together with a naughty mini',
#  'together with a naughty mini vampire',
#  'with a naughty mini vampire while',
#  'a naughty mini vampire while finding',
#  'naughty mini vampire while finding new',
#  'mini vampire while finding new water',
#  'vampire while finding new water sources',
#  'while finding new water sources one',
#  'finding new water sources one day',
#  'new water sources one day the',
#  'water sources one day the priest',
#  'sources one day the priest encounters',
#  'one day the priest encounters a',
#  'day the priest encounters a european',
#  'the priest encounters a european vampire',
#  'priest encounters a european vampire in',
#  'encounters a european vampire in the',
#  'a european vampire in the nearby',
#  'european vampire in the nearby church',
#  'vampire in the nearby church who',
#  'in the nearby church who is',
#  'the nearby church who is aided',
#  'nearby church who is aided by',
#  'church who is aided by a',
#  'who is aided by a dead',
#  'is aided by a dead countess',
#  'aided by a dead countess although',
#  'by a dead countess although the',
#  'a dead countess although the priest',
#  'dead countess although the priest manages',
#  'countess although the priest manages to',
#  'although the priest manages to get',
#  'the priest manages to get rid',
#  'priest manages to get rid of',
#  'manages to get rid of the',
#  'to get rid of the countess',
#  'get rid of the countess his',
#  'rid of the countess his chinese',
#  'of the countess his chinese exorcism',
#  'the countess his chinese exorcism fails',
#  'countess his chinese exorcism fails on',
#  'his chinese exorcism fails on the',
#  'chinese exorcism fails on the european',
#  'exorcism fails on the european vampire',
#  'while playing baseball on a busy',
#  'playing baseball on a busy street',
#  'baseball on a busy street in',
#  'on a busy street in greenpoint',
#  'a busy street in greenpoint mickey',
#  'busy street in greenpoint mickey is',
#  'street in greenpoint mickey is struck',
#  'in greenpoint mickey is struck by',
#  'greenpoint mickey is struck by a',
#  'mickey is struck by a car',
#  'is struck by a car though',
#  'struck by a car though he',
#  'by a car though he fully',
#  'a car though he fully recovers',
#  'car though he fully recovers from',
#  'though he fully recovers from his',
#  'he fully recovers from his injuries',
#  'fully recovers from his injuries mickey',
#  'recovers from his injuries mickey meets',
#  'from his injuries mickey meets several',
#  'his injuries mickey meets several other',
#  'injuries mickey meets several other kids',
#  'mickey meets several other kids in',
#  'meets several other kids in the',
#  'several other kids in the hospital',
#  'other kids in the hospital who',
#  "kids in the hospital who weren't",
#  "in the hospital who weren't so",
#  "the hospital who weren't so lucky",
#  "hospital who weren't so lucky instantly",
#  "who weren't so lucky instantly developing",
#  "weren't so lucky instantly developing a",
#  'so lucky instantly developing a sense',
#  'lucky instantly developing a sense of',
#  'instantly developing a sense of civic',
#  'developing a sense of civic responsibility',
#  'a sense of civic responsibility the',
#  'sense of civic responsibility the gang',
#  'of civic responsibility the gang members',
#  'civic responsibility the gang members establish',
#  'responsibility the gang members establish the',
#  'the gang members establish the go',
#  'gang members establish the go safety',
#  'members establish the go safety society',
#  'establish the go safety society dedicated',
#  'the go safety society dedicated to',
#  'go safety society dedicated to lowering',
#  'safety society dedicated to lowering the',
#  'society dedicated to lowering the number',
#  'dedicated to lowering the number of',
#  'to lowering the number of auto',
#  'lowering the number of auto injuries',
#  'the number of auto injuries in',
#  'number of auto injuries in their',
#  'of auto injuries in their communityref',
#  'auto injuries in their communityref namehttpmoviesnytimescommoviegooverview',
#  'injuries in their communityref namehttpmoviesnytimescommoviegooverview titleworkny',
#  'in their communityref namehttpmoviesnytimescommoviegooverview titleworkny times',
#  'thadeous and fabious danny mcbride are',
#  'and fabious danny mcbride are sons',
#  'fabious danny mcbride are sons of',
#  'danny mcbride are sons of king',
#  'mcbride are sons of king tallious',
#  'are sons of king tallious they',
#  'sons of king tallious they are',
#  'of king tallious they are warriors',
#  'king tallious they are warriors fabious',
#  'tallious they are warriors fabious is',
#  'they are warriors fabious is dashing',
#  'are warriors fabious is dashing and',
#  'warriors fabious is dashing and skilled',
#  'fabious is dashing and skilled and',
#  'is dashing and skilled and thadeous',
#  'dashing and skilled and thadeous is',
#  'and skilled and thadeous is lazy',
#  'skilled and thadeous is lazy and',
#  'and thadeous is lazy and ineffectual',
#  'thadeous is lazy and ineffectual while',
#  'is lazy and ineffectual while celebrating',
#  'lazy and ineffectual while celebrating his',
#  'and ineffectual while celebrating his latest',
#  'ineffectual while celebrating his latest victory',
#  'while celebrating his latest victory over',
#  'celebrating his latest victory over the',
#  'his latest victory over the evil',
#  'latest victory over the evil sorcerer',
#  'victory over the evil sorcerer who',
#  'over the evil sorcerer who has',
#  'the evil sorcerer who has been',
#  'evil sorcerer who has been ravaging',
#  "sorcerer who has been ravaging tallious's",
#  "who has been ravaging tallious's kingdom",
#  "has been ravaging tallious's kingdom leezar",
#  "been ravaging tallious's kingdom leezar fabious",
#  "ravaging tallious's kingdom leezar fabious introduces",
#  "tallious's kingdom leezar fabious introduces the",
#  'kingdom leezar fabious introduces the virgin',
#  'leezar fabious introduces the virgin belladonna',
#  'fabious introduces the virgin belladonna he',
#  'introduces the virgin belladonna he freed',
#  'the virgin belladonna he freed from',
#  'virgin belladonna he freed from a',
#  'belladonna he freed from a tower',
#  'he freed from a tower and',
#  'freed from a tower and wishes',
#  'from a tower and wishes to',
#  'a tower and wishes to marry',
#  'tower and wishes to marry her',
#  'and wishes to marry her though',
#  'wishes to marry her though he',
#  'to marry her though he is',
#  'marry her though he is made',
#  'her though he is made the',
#  'though he is made the best',
#  'he is made the best man',
#  'is made the best man thadeous',
#  'made the best man thadeous skips',
#  'the best man thadeous skips the',
#  'best man thadeous skips the wedding',
#  'man thadeous skips the wedding after',
#  'thadeous skips the wedding after overhearing',
#  "skips the wedding after overhearing fabious's",
#  "the wedding after overhearing fabious's knights",
#  "wedding after overhearing fabious's knights elite",
#  "after overhearing fabious's knights elite led",
#  "overhearing fabious's knights elite led by",
#  "fabious's knights elite led by boremont",
#  'knights elite led by boremont talk',
#  'elite led by boremont talk about',
#  'led by boremont talk about him',
#  'by boremont talk about him negatively',
#  'boremont talk about him negatively but',
#  'talk about him negatively but the',
#  'about him negatively but the wedding',
#  'him negatively but the wedding is',
#  'negatively but the wedding is then',
#  'but the wedding is then crashed',
#  'the wedding is then crashed by',
#  'wedding is then crashed by leezar',
#  'is then crashed by leezar revealing',
#  'then crashed by leezar revealing himself',
#  'crashed by leezar revealing himself to',
#  'by leezar revealing himself to be',
#  'leezar revealing himself to be the',
#  'revealing himself to be the one',
#  'himself to be the one who',
#  'to be the one who placed',
#  'be the one who placed belladona',
#  'the one who placed belladona in',
#  'one who placed belladona in the',
#  'who placed belladona in the tower',
#  'placed belladona in the tower before',
#  'belladona in the tower before spiriting',
#  'in the tower before spiriting her',
#  'the tower before spiriting her away',
#  'tower before spiriting her away returning',
#  'before spiriting her away returning to',
#  'spiriting her away returning to the',
#  'her away returning to the castle',
#  'away returning to the castle with',
#  'returning to the castle with his',
#  'to the castle with his servant',
#  'the castle with his servant courtney',
#  'castle with his servant courtney thadeous',
#  'with his servant courtney thadeous is',
#  'his servant courtney thadeous is forced',
#  'servant courtney thadeous is forced into',
#  'courtney thadeous is forced into joining',
#  'thadeous is forced into joining fabious',
#  'is forced into joining fabious on',
#  'forced into joining fabious on his',
#  'into joining fabious on his quest',
#  'joining fabious on his quest to',
#  'fabious on his quest to rescue',
#  'on his quest to rescue belladonna',
#  'his quest to rescue belladonna visiting',
#  'quest to rescue belladonna visiting the',
#  'to rescue belladonna visiting the great',
#  'rescue belladonna visiting the great wise',
#  'belladonna visiting the great wise wizard',
#  'visiting the great wise wizard thadeous',
#  'the great wise wizard thadeous and',
#  'great wise wizard thadeous and fabious',
#  'wise wizard thadeous and fabious learn',
#  'wizard thadeous and fabious learn that',
#  'thadeous and fabious learn that leezar',
#  'and fabious learn that leezar is',
#  'fabious learn that leezar is attempting',
#  'learn that leezar is attempting to',
#  'that leezar is attempting to fulfill',
#  'leezar is attempting to fulfill a',
#  'is attempting to fulfill a prophecy',
#  'attempting to fulfill a prophecy of',
#  'to fulfill a prophecy of a',
#  'fulfill a prophecy of a warlock',
#  'a prophecy of a warlock having',
#  'prophecy of a warlock having sex',
#  'of a warlock having sex with',
#  'a warlock having sex with a',
#  'warlock having sex with a maiden',
#  'having sex with a maiden when',
#  'sex with a maiden when the',
#  'with a maiden when the two',
#  'a maiden when the two moons',
#  'maiden when the two moons converge',
#  'when the two moons converge impregnating',
#  'the two moons converge impregnating her',
#  'two moons converge impregnating her with',
#  'moons converge impregnating her with a',
#  'converge impregnating her with a dragon',
#  'impregnating her with a dragon that',
#  'her with a dragon that will',
#  'with a dragon that will allow',
#  'a dragon that will allow him',
#  'dragon that will allow him to',
#  'that will allow him to take',
#  'will allow him to take over',
#  'allow him to take over king',
#  "him to take over king tallious'",
#  "to take over king tallious' kingdom",
#  "take over king tallious' kingdom to",
#  "over king tallious' kingdom to destroy",
#  "king tallious' kingdom to destroy leezar",
#  "tallious' kingdom to destroy leezar they",
#  'kingdom to destroy leezar they are',
#  'to destroy leezar they are given',
#  'destroy leezar they are given a',
#  'leezar they are given a magic',
#  'they are given a magic compass',
#  'are given a magic compass that',
#  'given a magic compass that would',
#  'a magic compass that would lead',
#  'magic compass that would lead them',
#  'compass that would lead them to',
#  'that would lead them to the',
#  'would lead them to the blade',
#  'lead them to the blade of',
#  'them to the blade of unicorn',
#  'to the blade of unicorn located',
#  'the blade of unicorn located within',
#  'blade of unicorn located within a',
#  'of unicorn located within a labyrinth',
#  'unicorn located within a labyrinth on',
#  'located within a labyrinth on the',
#  'within a labyrinth on the way',
#  'a labyrinth on the way there',
#  'labyrinth on the way there they',
#  'on the way there they learn',
#  "the way there they learn fabious's",
#  "way there they learn fabious's slave",
#  "there they learn fabious's slave julie",
#  "they learn fabious's slave julie has",
#  "learn fabious's slave julie has been",
#  "fabious's slave julie has been reporting",
#  'slave julie has been reporting to',
#  'julie has been reporting to leezar',
#  'has been reporting to leezar of',
#  'been reporting to leezar of their',
#  'reporting to leezar of their progress',
#  'to leezar of their progress and',
#  'leezar of their progress and the',
#  'of their progress and the knights',
#  'their progress and the knights elite',
#  'progress and the knights elite are',
#  'and the knights elite are serving',
#  'the knights elite are serving the',
#  'knights elite are serving the warlock',
#  'elite are serving the warlock after',
#  'are serving the warlock after his',
#  'serving the warlock after his brother',
#  'the warlock after his brother sends',
#  'warlock after his brother sends his',
#  'after his brother sends his mechanical',
#  'his brother sends his mechanical bird',
#  'brother sends his mechanical bird simon',
#  'sends his mechanical bird simon to',
#  'his mechanical bird simon to tell',
#  'mechanical bird simon to tell the',
#  'bird simon to tell the king',
#  'simon to tell the king of',
#  'to tell the king of the',
#  'tell the king of the betrayal',
#  'the king of the betrayal by',
#  'king of the betrayal by the',
#  'of the betrayal by the knights',
#  'the betrayal by the knights elite',
#  'betrayal by the knights elite and',
#  'by the knights elite and request',
#  'the knights elite and request reinforcements',
#  'knights elite and request reinforcements thadeous',
#  'elite and request reinforcements thadeous fabious',
#  'and request reinforcements thadeous fabious and',
#  'request reinforcements thadeous fabious and courtney',
#  'reinforcements thadeous fabious and courtney are',
#  'thadeous fabious and courtney are captured',
#  'fabious and courtney are captured by',
#  'and courtney are captured by nymphs',
#  'courtney are captured by nymphs under',
#  'are captured by nymphs under their',
#  'captured by nymphs under their leader',
#  'by nymphs under their leader marteetee',
#  'nymphs under their leader marteetee who',
#  'under their leader marteetee who imprisons',
#  'their leader marteetee who imprisons them',
#  'leader marteetee who imprisons them at',
#  'marteetee who imprisons them at an',
#  'who imprisons them at an arena',
#  'imprisons them at an arena where',
#  'them at an arena where fabious',
#  'at an arena where fabious kills',
#  'an arena where fabious kills off',
#  "arena where fabious kills off marteetee's",
#  "where fabious kills off marteetee's finest",
#  "fabious kills off marteetee's finest warrior",
#  "kills off marteetee's finest warrior in",
#  "off marteetee's finest warrior in retaliation",
#  "marteetee's finest warrior in retaliation marteetee",
#  'finest warrior in retaliation marteetee summons',
#  'warrior in retaliation marteetee summons his',
#  'in retaliation marteetee summons his hydralike',
#  'retaliation marteetee summons his hydralike familiar',
#  'marteetee summons his hydralike familiar to',
#  'summons his hydralike familiar to kill',
#  'his hydralike familiar to kill them',
#  'hydralike familiar to kill them thadeous',
#  'familiar to kill them thadeous and',
#  'to kill them thadeous and fabious',
#  'kill them thadeous and fabious are',
#  'them thadeous and fabious are rescued',
#  'thadeous and fabious are rescued by',
#  'and fabious are rescued by isabel',
#  'fabious are rescued by isabel a',
#  'are rescued by isabel a warrior',
#  'rescued by isabel a warrior seeking',
#  'by isabel a warrior seeking revenge',
#  'isabel a warrior seeking revenge for',
#  'a warrior seeking revenge for her',
#  "warrior seeking revenge for her father's",
#  "seeking revenge for her father's murder",
#  "revenge for her father's murder at",
#  "for her father's murder at marteetee's",
#  "her father's murder at marteetee's hands",
#  "father's murder at marteetee's hands later",
#  "murder at marteetee's hands later that",
#  "at marteetee's hands later that night",
#  "marteetee's hands later that night thadeous",
#  'hands later that night thadeous learns',
#  'later that night thadeous learns that',
#  'that night thadeous learns that isabel',
#  'night thadeous learns that isabel is',
#  'thadeous learns that isabel is also',
#  'learns that isabel is also after',
#  'that isabel is also after leezar',
#  'isabel is also after leezar for',
#  'is also after leezar for the',
#  'also after leezar for the slaughter',
#  'after leezar for the slaughter of',
#  'leezar for the slaughter of her',
#  'for the slaughter of her brothers',
#  'the slaughter of her brothers the',
#  'slaughter of her brothers the next',
#  'of her brothers the next day',
#  'her brothers the next day the',
#  'brothers the next day the party',
#  'the next day the party learn',
#  'next day the party learn too',
#  'day the party learn too late',
#  'the party learn too late that',
#  'party learn too late that isabel',
#  'learn too late that isabel stole',
#  'too late that isabel stole the',
#  'late that isabel stole the compass',
#  'that isabel stole the compass from',
#  'isabel stole the compass from thadeous',
#  'stole the compass from thadeous fabious',
#  'the compass from thadeous fabious decides',
#  'compass from thadeous fabious decides to',
#  'from thadeous fabious decides to find',
#  'thadeous fabious decides to find the',
#  'fabious decides to find the blade',
#  'decides to find the blade of',
#  'to find the blade of unicorn',
#  'find the blade of unicorn alone',
#  'the blade of unicorn alone as',
#  'blade of unicorn alone as thadeous',
#  'of unicorn alone as thadeous and',
#  'unicorn alone as thadeous and courtney',
#  'alone as thadeous and courtney go',
#  'as thadeous and courtney go to',
#  'thadeous and courtney go to a',
#  'and courtney go to a tavern',
#  'courtney go to a tavern where',
#  'go to a tavern where they',
#  'to a tavern where they find',
#  'a tavern where they find isabel',
#  'tavern where they find isabel and',
#  'where they find isabel and steal',
#  'they find isabel and steal the',
#  'find isabel and steal the compass',
#  'isabel and steal the compass back',
#  'and steal the compass back but',
#  'steal the compass back but finding',
#  'the compass back but finding that',
#  'compass back but finding that his',
#  'back but finding that his brother',
#  'but finding that his brother has',
#  'finding that his brother has been',
#  'that his brother has been captured',
#  'his brother has been captured by',
#  "brother has been captured by leezar's",
#  "has been captured by leezar's men",
#  "been captured by leezar's men thadeous",
#  "captured by leezar's men thadeous wins",
#  "by leezar's men thadeous wins isabel",
#  "leezar's men thadeous wins isabel over",
#  'men thadeous wins isabel over as',
#  'thadeous wins isabel over as they',
#  'wins isabel over as they join',
#  'isabel over as they join forces',
#  'over as they join forces entering',
#  'as they join forces entering the',
#  'they join forces entering the labyrinth',
#  'join forces entering the labyrinth where',
#  'forces entering the labyrinth where they',
#  'entering the labyrinth where they encounter',
#  'the labyrinth where they encounter a',
#  'labyrinth where they encounter a minotaur',
#  'where they encounter a minotaur getting',
#  'they encounter a minotaur getting separated',
#  'encounter a minotaur getting separated from',
#  'a minotaur getting separated from the',
#  'minotaur getting separated from the others',
#  'getting separated from the others thadeous',
#  'separated from the others thadeous retrieves',
#  'from the others thadeous retrieves the',
#  'the others thadeous retrieves the blade',
#  'others thadeous retrieves the blade of',
#  'thadeous retrieves the blade of unicorn',
#  'retrieves the blade of unicorn and',
#  'the blade of unicorn and slays',
#  'blade of unicorn and slays the',
#  'of unicorn and slays the minotaur',
#  'unicorn and slays the minotaur thadeous',
#  'and slays the minotaur thadeous and',
#  'slays the minotaur thadeous and his',
#  'the minotaur thadeous and his group',
#  'minotaur thadeous and his group make',
#  'thadeous and his group make their',
#  'and his group make their way',
#  'his group make their way to',
#  "group make their way to leezar's",
#  "make their way to leezar's castle",
#  "their way to leezar's castle and",
#  "way to leezar's castle and free",
#  "to leezar's castle and free fabious",
#  "leezar's castle and free fabious while",
#  'castle and free fabious while giving',
#  'and free fabious while giving him',
#  'free fabious while giving him the',
#  'fabious while giving him the sword',
#  'while giving him the sword of',
#  'giving him the sword of unicorn',
#  'him the sword of unicorn as',
#  'the sword of unicorn as the',
#  'sword of unicorn as the others',
#  'of unicorn as the others kill',
#  'unicorn as the others kill off',
#  'as the others kill off julie',
#  'the others kill off julie and',
#  "others kill off julie and boremont's",
#  "kill off julie and boremont's men",
#  "off julie and boremont's men along",
#  "julie and boremont's men along with",
#  "and boremont's men along with leezar's",
#  "boremont's men along with leezar's mothers",
#  "men along with leezar's mothers fabious",
#  "along with leezar's mothers fabious uses",
#  "with leezar's mothers fabious uses the",
#  "leezar's mothers fabious uses the blade",
#  'mothers fabious uses the blade of',
#  'fabious uses the blade of unicorn',
#  'uses the blade of unicorn to',
#  'the blade of unicorn to end',
#  "blade of unicorn to end leezar's",
#  "of unicorn to end leezar's life",
#  "unicorn to end leezar's life before",
#  "to end leezar's life before he",
#  "end leezar's life before he can",
#  "leezar's life before he can rape",
#  'life before he can rape belladonna',
#  'before he can rape belladonna saving',
#  'he can rape belladonna saving the',
#  'can rape belladonna saving the kingdom',
#  'rape belladonna saving the kingdom after',
#  'belladonna saving the kingdom after their',
#  'saving the kingdom after their victory',
#  'the kingdom after their victory isabel',
#  'kingdom after their victory isabel goes',
#  'after their victory isabel goes on',
#  'their victory isabel goes on another',
#  'victory isabel goes on another quest',
#  'isabel goes on another quest and',
#  'goes on another quest and the',
#  'on another quest and the heroes',
#  'another quest and the heroes return',
#  'quest and the heroes return home',
#  'and the heroes return home fabious',
#  'the heroes return home fabious and',
#  'heroes return home fabious and belladonna',
#  'return home fabious and belladonna marry',
#  'home fabious and belladonna marry thadeous',
#  'fabious and belladonna marry thadeous is',
#  'and belladonna marry thadeous is approached',
#  'belladonna marry thadeous is approached by',
#  'marry thadeous is approached by isabel',
#  'thadeous is approached by isabel who',
#  'is approached by isabel who reveals',
#  'approached by isabel who reveals that',
#  'by isabel who reveals that she',
#  'isabel who reveals that she has',
#  'who reveals that she has fallen',
#  'reveals that she has fallen in',
#  'that she has fallen in love',
#  'she has fallen in love with',
#  'has fallen in love with him',
#  'fallen in love with him however',
#  'in love with him however for',
#  'love with him however for them',
#  'with him however for them to',
#  'him however for them to have',
#  'however for them to have sex',
#  'for them to have sex he',
#  'them to have sex he must',
#  'to have sex he must first',
#  'have sex he must first slay',
#  'sex he must first slay the',
#  'he must first slay the witch',
#  'must first slay the witch that',
#  'first slay the witch that cast',
#  'slay the witch that cast a',
#  'the witch that cast a spell',
#  'witch that cast a spell on',
#  'that cast a spell on her',
#  'cast a spell on her locking',
#  'a spell on her locking her',
#  'spell on her locking her in',
#  'on her locking her in a',
#  'her locking her in a chastity',
#  'locking her in a chastity belt',
#  'her in a chastity belt though',
#  'in a chastity belt though he',
#  'a chastity belt though he is',
#  'chastity belt though he is not',
#  'belt though he is not in',
#  'though he is not in the',
#  'he is not in the mood',
#  'is not in the mood to',
#  'not in the mood to go',
#  'in the mood to go out',
#  "the mood to go out isabel's",
#  "mood to go out isabel's suggestion",
#  "to go out isabel's suggestion convinces",
#  "go out isabel's suggestion convinces him",
#  "out isabel's suggestion convinces him to",
#  "isabel's suggestion convinces him to go",
#  'suggestion convinces him to go on',
#  'convinces him to go on a',
#  'him to go on a new',
#  'to go on a new adventure',
#  'plot jung suji is a quiet',
#  'jung suji is a quiet mysterious',
#  'suji is a quiet mysterious beauty',
#  'is a quiet mysterious beauty whenever',
#  'a quiet mysterious beauty whenever she',
#  'quiet mysterious beauty whenever she speaks',
#  'mysterious beauty whenever she speaks to',
#  'beauty whenever she speaks to nami',
#  'whenever she speaks to nami it',
#  'she speaks to nami it is',
#  'speaks to nami it is always',
#  'to nami it is always with',
#  'nami it is always with disdaintowards',
#  'it is always with disdaintowards the',
#  'is always with disdaintowards the end',
#  'always with disdaintowards the end of',
#  'with disdaintowards the end of the',
#  'disdaintowards the end of the film',
#  'the end of the film nami',
#  'end of the film nami confronts',
#  'of the film nami confronts suji',
#  'the film nami confronts suji and',
#  'film nami confronts suji and learns',
#  'nami confronts suji and learns that',
#  'confronts suji and learns that sujis',
#  'suji and learns that sujis stepmother',
#  'and learns that sujis stepmother is',
#  'learns that sujis stepmother is from',
#  'that sujis stepmother is from jeollado',
#  'sujis stepmother is from jeollado the',
#  'stepmother is from jeollado the same',
#  'is from jeollado the same city',
#  'from jeollado the same city nami',
#  'jeollado the same city nami is',
#  'the same city nami is from',
#  'same city nami is from making',
#  'city nami is from making suji',
#  'nami is from making suji automatically',
#  'is from making suji automatically biased',
#  'from making suji automatically biased against',
#  'making suji automatically biased against nami',
#  'suji automatically biased against nami the',
#  'automatically biased against nami the two',
#  'biased against nami the two make',
#  'against nami the two make up',
#  'nami the two make up after',
#  'the two make up after drinking',
#  'two make up after drinking soju',
#  'make up after drinking soju and',
#  'up after drinking soju and crying',
#  'after drinking soju and crying out',
#  'drinking soju and crying out their',
#  'soju and crying out their frustrations',
#  'and crying out their frustrations together',
#  'crying out their frustrations together nami',
#  'out their frustrations together nami is',
#  'their frustrations together nami is accepted',
#  'frustrations together nami is accepted into',
#  'together nami is accepted into their',
#  'nami is accepted into their group',
#  'is accepted into their group as',
#  'accepted into their group as their',
#  'into their group as their seventh',
#  'their group as their seventh member',
#  'group as their seventh member after',
#  'as their seventh member after she',
#  'their seventh member after she unexpectedly',
#  'seventh member after she unexpectedly proves',
#  'member after she unexpectedly proves herself',
#  'after she unexpectedly proves herself against',
#  'she unexpectedly proves herself against a',
#  'unexpectedly proves herself against a rival',
#  'proves herself against a rival group',
#  'herself against a rival group from',
#  'against a rival group from a',
#  'a rival group from a different',
#  'rival group from a different school',
#  'group from a different school chiunhwa',
#  'from a different school chiunhwa suggests',
#  'a different school chiunhwa suggests naming',
#  'different school chiunhwa suggests naming their',
#  'school chiunhwa suggests naming their group',
#  'chiunhwa suggests naming their group they',
#  'suggests naming their group they settle',
#  'naming their group they settle on',
#  'their group they settle on sunny',
#  'group they settle on sunny after',
#  'they settle on sunny after a',
#  'settle on sunny after a nighttime',
#  'on sunny after a nighttime radio',
#  'sunny after a nighttime radio dj',
#  'after a nighttime radio dj responds',
#  'a nighttime radio dj responds to',
#  'nighttime radio dj responds to their',
#  'radio dj responds to their letter',
#  'dj responds to their letter on',
#  'responds to their letter on air',
#  'to their letter on air back',
#  'their letter on air back at',
#  'letter on air back at the',
#  'on air back at the present',
#  'air back at the present time',
#  'back at the present time nami',
#  'at the present time nami returns',
#  'the present time nami returns to',
#  "present time nami returns to chiunhwa's",
#  "time nami returns to chiunhwa's room",
#  "nami returns to chiunhwa's room and",
#  "returns to chiunhwa's room and confirms",
#  "to chiunhwa's room and confirms it",
#  "chiunhwa's room and confirms it is",
#  'room and confirms it is indeed',
#  'and confirms it is indeed her',
#  'confirms it is indeed her high',
#  'it is indeed her high school',
#  'is indeed her high school friend',
#  'indeed her high school friend she',
#  'her high school friend she learns',
#  'high school friend she learns that',
#  'school friend she learns that chiunhwa',
#  'friend she learns that chiunhwa became',
#  'she learns that chiunhwa became a',
#  'learns that chiunhwa became a successful',
#  'that chiunhwa became a successful businesswoman',
#  'chiunhwa became a successful businesswoman but',
#  'became a successful businesswoman but has',
#  'a successful businesswoman but has terminal',
#  'successful businesswoman but has terminal cancer',
#  'businesswoman but has terminal cancer with',
#  'but has terminal cancer with two',
#  'has terminal cancer with two months',
#  'terminal cancer with two months to',
#  'cancer with two months to live',
#  'with two months to live namis',
#  'two months to live namis husband',
#  'months to live namis husband calls',
#  'to live namis husband calls and',
#  'live namis husband calls and informs',
#  'namis husband calls and informs her',
#  'husband calls and informs her that',
#  'calls and informs her that he',
#  'and informs her that he is',
#  'informs her that he is on',
#  'her that he is on a',
#  'that he is on a twomonth',
#  'he is on a twomonth business',
#  'is on a twomonth business trip',
#  'on a twomonth business trip as',
#  'a twomonth business trip as nami',
#  'twomonth business trip as nami leaves',
#  'business trip as nami leaves she',
#  'trip as nami leaves she promises',
#  'as nami leaves she promises she',
#  'nami leaves she promises she will',
#  'leaves she promises she will visit',
#  'she promises she will visit often',
#  'promises she will visit often chiunhwa',
#  'she will visit often chiunhwa then',
#  'will visit often chiunhwa then tells',
#  'visit often chiunhwa then tells her',
#  'often chiunhwa then tells her she',
#  'chiunhwa then tells her she would',
#  'then tells her she would like',
#  'tells her she would like to',
#  'her she would like to see',
#  'she would like to see sunny',
#  'would like to see sunny reunited',
#  'like to see sunny reunited one',
#  'to see sunny reunited one more',
#  'see sunny reunited one more time',
#  'sunny reunited one more time before',
#  'reunited one more time before she',
#  'one more time before she diesref',
#  'more time before she diesref nameseptember',
#  'time before she diesref nameseptember reasondo',
#  'before she diesref nameseptember reasondo they',
#  'she diesref nameseptember reasondo they reunite',
#  'diesref nameseptember reasondo they reunite before',
#  'nameseptember reasondo they reunite before the',
#  'reasondo they reunite before the funeral',
#  'they reunite before the funeral or',
#  'reunite before the funeral or at',
#  'before the funeral or at the',
#  'the funeral or at the funeral',
#  'funeral or at the funeral at',
#  "or at the funeral at chiunhwa's",
#  "at the funeral at chiunhwa's funeral",
#  "the funeral at chiunhwa's funeral sunny",
#  "funeral at chiunhwa's funeral sunny is",
#  "at chiunhwa's funeral sunny is reunited",
#  "chiunhwa's funeral sunny is reunited but",
#  'funeral sunny is reunited but not',
#  'sunny is reunited but not every',
#  'is reunited but not every woman',
#  'reunited but not every woman knows',
#  'but not every woman knows about',
#  'not every woman knows about each',
#  "every woman knows about each other's",
#  "woman knows about each other's present",
#  "knows about each other's present struggles",
#  "about each other's present struggles as",
#  "each other's present struggles as they",
#  "other's present struggles as they are",
#  'present struggles as they are about',
#  'struggles as they are about to',
#  'as they are about to leave',
#  "they are about to leave chiunhwa's",
#  "are about to leave chiunhwa's lawyer",
#  "about to leave chiunhwa's lawyer walks",
#  "to leave chiunhwa's lawyer walks in",
#  "leave chiunhwa's lawyer walks in and",
#  "chiunhwa's lawyer walks in and asks",
#  'lawyer walks in and asks them',
#  'walks in and asks them if',
#  'in and asks them if they',
#  'and asks them if they are',
#  'asks them if they are sunny',
#  'them if they are sunny he',
#  'if they are sunny he reads',
#  "they are sunny he reads chiunhwa's",
#  "are sunny he reads chiunhwa's will",
#  "sunny he reads chiunhwa's will which",
#  "he reads chiunhwa's will which bequeathes",
#  "reads chiunhwa's will which bequeathes that",
#  "chiunhwa's will which bequeathes that nami",
#  'will which bequeathes that nami will',
#  'which bequeathes that nami will be',
#  'bequeathes that nami will be the',
#  ...]

# %%
# movie_plots[0]

# %%
# create inputs and targets (x and y)
x = []
y = []

for s in seqs:
    x.append(" ".join(s.split()[:-1]))
    y.append(" ".join(s.split()[1:]))

# %%
x[1]
# Out:
# 'is a private with the'

# %%
y[1]
# Out:
# 'a private with the st'

# %%
# create integer-to-token mapping
int2token = {}
cnt = 0

for w in set(" ".join(movie_plots).split()):
    int2token[cnt] = w
    cnt+= 1

# create token-to-integer mapping
token2int = {t: i for i, t in int2token.items()}

token2int["the"], int2token[14271]
# Out:
# (9406, 'dupe')

# %%
# torch.save(token2int,'/home/taindp/VINBRAIN_INTERNSHIP/nlg_lstm/resource/token2int.h5')
# torch.save(int2token,'/home/taindp/VINBRAIN_INTERNSHIP/nlg_lstm/resource/int2token.h5')

# %%
# set vocabulary size
vocab_size = len(int2token)
vocab_size
# Out:
# 16592

# %%
def get_integer_seq(seq):
    return [token2int[w] for w in seq.split()]

# convert text sequences to integer sequences
x_int = [get_integer_seq(i) for i in x]
y_int = [get_integer_seq(i) for i in y]

# convert lists to numpy arrays
x_int = np.array(x_int)
y_int = np.array(y_int)

# %% [markdown]
# # Model Building

# %%
def get_batches(arr_x, arr_y, batch_size):
         
    # iterate through the arrays
    prv = 0
    for n in range(batch_size, arr_x.shape[0], batch_size):
        x = arr_x[prv:n,:]
        y = arr_y[prv:n,:]
        prv = n
        yield x, y

# %%
class WordLSTM(nn.Module):
    
    def __init__(self, n_hidden=256, n_layers=4, drop_prob=0.3, lr=0.001):
        super().__init__()

        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        self.emb_layer = nn.Embedding(vocab_size, 200)

        ## define the LSTM
        self.lstm = nn.LSTM(200, n_hidden, n_layers, 
                            dropout=drop_prob, batch_first=True)
        
        ## define a dropout layer
        self.dropout = nn.Dropout(drop_prob)
        
        ## define the fully-connected layer
        self.fc = nn.Linear(n_hidden, vocab_size)      
    
    def forward(self, x, hidden):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hidden`. '''

        ## pass input through embedding layer
        embedded = self.emb_layer(x)     
        
        ## Get the outputs and the new hidden state from the lstm
        lstm_output, hidden = self.lstm(embedded, hidden)
        
        ## pass through a dropout layer
        out = self.dropout(lstm_output)
        
        #out = out.contiguous().view(-1, self.n_hidden) 
        out = out.reshape(-1, self.n_hidden) 

        ## put "out" through the fully-connected layer
        out = self.fc(out)

        # return the final output and the hidden state
        return out, hidden
    
    
    def init_hidden(self, batch_size):
        ''' initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data

        # if GPU is available
        if (torch.cuda.is_available()):
            hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        
        # if GPU is not available
        else:
            hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        
        return hidden

# %%
net = WordLSTM()

print(net)
# Out:
# WordLSTM(
#   (emb_layer): Embedding(16592, 200)
#   (lstm): LSTM(200, 256, num_layers=4, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=16592, bias=True)
# )

# %%
def train(net, epochs=10, batch_size=32, lr=0.001, clip=1, print_every=32):
    
    # optimizer
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    
    # loss
    criterion = nn.CrossEntropyLoss()
    
    # push model to GPU
    net.cuda()
    
    counter = 0

    net.train()

    for e in range(epochs):

        # initialize hidden state
        h = net.init_hidden(batch_size)
        
        for x, y in get_batches(x_int, y_int, batch_size):
            counter+= 1
            
            # convert numpy arrays to PyTorch arrays
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
            
            # push tensors to GPU
            inputs, targets = inputs.cuda(), targets.cuda()

            # detach hidden states
            h = tuple([each.data for each in h])

            # zero accumulated gradients
            net.zero_grad()
            
            # get the output from the model
            output, h = net(inputs, h)
            
            # calculate the loss and perform backprop
            loss = criterion(output, targets.view(-1))

            # back-propagate error
            loss.backward()

            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)

            # update weigths
            opt.step()            
            
            if counter % print_every == 0:
            
              print("Epoch: {}/{}...".format(e+1, epochs),
                    "Step: {}...".format(counter))

# %%
# train the model
train(net, batch_size = 32, epochs=20, print_every=256)
# Out:
# Epoch: 1/20... Step: 256...
# Epoch: 1/20... Step: 512...
# Epoch: 1/20... Step: 768...
# Epoch: 1/20... Step: 1024...
# Epoch: 1/20... Step: 1280...
# Epoch: 1/20... Step: 1536...
# Epoch: 1/20... Step: 1792...
# Epoch: 1/20... Step: 2048...
# Epoch: 1/20... Step: 2304...
# Epoch: 1/20... Step: 2560...
# Epoch: 1/20... Step: 2816...
# Epoch: 1/20... Step: 3072...
# Epoch: 1/20... Step: 3328...
# Epoch: 1/20... Step: 3584...
# Epoch: 1/20... Step: 3840...
# Epoch: 1/20... Step: 4096...
# Epoch: 1/20... Step: 4352...
# Epoch: 1/20... Step: 4608...
# Epoch: 2/20... Step: 4864...
# Epoch: 2/20... Step: 5120...
# Epoch: 2/20... Step: 5376...
# Epoch: 2/20... Step: 5632...
# Epoch: 2/20... Step: 5888...
# Epoch: 2/20... Step: 6144...
# Epoch: 2/20... Step: 6400...
# Epoch: 2/20... Step: 6656...
# Epoch: 2/20... Step: 6912...
# Epoch: 2/20... Step: 7168...
# Epoch: 2/20... Step: 7424...
# Epoch: 2/20... Step: 7680...
# Epoch: 2/20... Step: 7936...
# Epoch: 2/20... Step: 8192...
# Epoch: 2/20... Step: 8448...
# Epoch: 2/20... Step: 8704...
# Epoch: 2/20... Step: 8960...
# Epoch: 2/20... Step: 9216...
# Epoch: 2/20... Step: 9472...
# Epoch: 3/20... Step: 9728...
# Epoch: 3/20... Step: 9984...
# Epoch: 3/20... Step: 10240...
# Epoch: 3/20... Step: 10496...
# Epoch: 3/20... Step: 10752...
# Epoch: 3/20... Step: 11008...
# Epoch: 3/20... Step: 11264...
# Epoch: 3/20... Step: 11520...
# Epoch: 3/20... Step: 11776...
# Epoch: 3/20... Step: 12032...
# Epoch: 3/20... Step: 12288...
# Epoch: 3/20... Step: 12544...
