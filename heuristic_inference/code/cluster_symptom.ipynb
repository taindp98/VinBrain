# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import re
from utils import flatten_lol,remove_multi_space
import os
import pymongo
import nltk

# %%
nltk.download ()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
_DATASET = '/home/taindp/VINBRAIN_INTERNSHIP/explore_kb/data/dataset.csv'
dataset = pd.read_csv(_DATASET)
dataset = dataset.fillna('none_symptom')
dataset.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4     Symptom_5     Symptom_6     Symptom_7  \
# 0   dischromic _patches  none_symptom  none_symptom  none_symptom
# 1          none_symptom  none_symptom  none_symptom  none_symptom
# 2          none_symptom  none_symptom  none_symptom  none_symptom
# 3          none_symptom  none_symptom  none_symptom  none_symptom
# 4          none_symptom  none_symptom  none_symptom  none_symptom
#
#       Symptom_8     Symptom_9    Symptom_10    Symptom_11    Symptom_12  \
# 0  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 1  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 2  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 3  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 4  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
#
#      Symptom_13    Symptom_14    Symptom_15    Symptom_16    Symptom_17
# 0  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 1  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 2  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 3  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom
# 4  none_symptom  none_symptom  none_symptom  none_symptom  none_symptom

# %%
list_cols = list(dataset.columns)
list_cols.pop(0)
list_merge_full = []
for idx in range(len(dataset)):
    if idx < len(dataset):
        df = dataset[idx:idx+1]
    else:
        df = dataset[idx:]
        
    list_merge_row = []
    for col in list_cols:
        symp = list(df[col])[0]
        if symp not in list_merge_row and symp != 'none_symptom':
            list_merge_row.append(symp)
    list_merge_full.append(list_merge_row)

# %%
dataset['Symptom'] = list_merge_full
dataset_groupby = dataset.groupby('Disease')['Symptom'].apply(list).reset_index(name='Symptom')
dataset_groupby['Symptom'] = [list(set(flatten_lol(item))) for item in list(dataset_groupby['Symptom'])]
dataset_groupby.head()
# Out:
#                                    Disease  \
# 0  (vertigo) Paroymsal  Positional Vertigo
# 1                                     AIDS
# 2                                     Acne
# 3                      Alcoholic hepatitis
# 4                                  Allergy
#
#                                              Symptom
# 0  [ spinning_movements,  vomiting,  headache,  n...
# 1  [ high_fever,  muscle_wasting,  patches_in_thr...
# 2  [ scurring,  blackheads,  skin_rash,  pus_fill...
# 3  [ yellowish_skin,  vomiting,  fluid_overload, ...
# 4  [ chills,  watering_from_eyes,  shivering,  co...

# %%
list_sympt_norm = []
for list_sympt in list(dataset_groupby['Symptom']):
    sublist_sympt_norm = []
    for sympt in list_sympt:
        if sympt.startswith(' '):
            norm_sympt = sympt[1:]
        else:
            norm_sympt = sympt
        sublist_sympt_norm.append(norm_sympt)
    list_sympt_norm.append(sublist_sympt_norm)

# %%
dataset_groupby['Symptom'] = list_sympt_norm

# %%
list_full_sympt = list(set(flatten_lol(list(dataset_groupby['Symptom']))))
len(list_full_sympt)
# Out:
# 131

# %%
list_full_sympt_split = []
for item in list_full_sympt:
    text_sympt = ' '.join(item.split('_'))
    tokens = nltk.word_tokenize(text_sympt)
    tag = nltk.pos_tag(tokens)
    print(tag)
#     list_full_sympt_split.append()
# list_full_sympt_split
# Out:
# [('breathlessness', 'NN')]
# [('muscle', 'NN'), ('wasting', 'VBG')]
# [('itching', 'VBG')]
# [('obesity', 'NN')]
# [('scurring', 'VBG')]
# [('weight', 'NN'), ('gain', 'NN')]
# [('continuous', 'JJ'), ('feel', 'NN'), ('of', 'IN'), ('urine', 'NN')]
# [('cough', 'NN')]
# [('knee', 'NN'), ('pain', 'NN')]
# [('yellowish', 'JJ'), ('skin', 'NN')]
# [('small', 'JJ'), ('dents', 'NNS'), ('in', 'IN'), ('nails', 'NNS')]
# [('brittle', 'NN'), ('nails', 'NNS')]
# [('hip', 'NN'), ('joint', 'NN'), ('pain', 'NN')]
# [('loss', 'NN'), ('of', 'IN'), ('balance', 'NN')]
# [('sweating', 'VBG')]
# [('slurred', 'VBN'), ('speech', 'NN')]
# [('shivering', 'VBG')]
# [('abnormal', 'JJ'), ('menstruation', 'NN')]
# [('headache', 'NN')]
# [('inflammatory', 'NN'), ('nails', 'NNS')]
# [('swollen', 'VBN'), ('blood', 'NN'), ('vessels', 'NNS')]
# [('altered', 'JJ'), ('sensorium', 'NN')]
# [('silver', 'NN'), ('like', 'IN'), ('dusting', 'VBG')]
# [('yellow', 'JJ'), ('crust', 'NN'), ('ooze', 'NN')]
# [('swollen', 'VBN'), ('legs', 'NNS')]
# [('acute', 'NN'), ('liver', 'NN'), ('failure', 'NN')]
# [('blood', 'NN'), ('in', 'IN'), ('sputum', 'NN')]
# [('depression', 'NN')]
# [('malaise', 'NN')]
# [('dizziness', 'NN')]
# [('puffy', 'JJ'), ('face', 'NN'), ('and', 'CC'), ('eyes', 'NNS')]
# [('congestion', 'NN')]
# [('receiving', 'VBG'), ('unsterile', 'JJ'), ('injections', 'NNS')]
# [('stiff', 'JJ'), ('neck', 'NN')]
# [('weakness', 'NN'), ('of', 'IN'), ('one', 'CD'), ('body', 'NN'), ('side', 'NN')]
# [('skin', 'NN'), ('peeling', 'NN')]
# [('loss', 'NN'), ('of', 'IN'), ('appetite', 'NN')]
# [('redness', 'NN'), ('of', 'IN'), ('eyes', 'NNS')]
# [('irritation', 'NN'), ('in', 'IN'), ('anus', 'NN')]
# [('history', 'NN'), ('of', 'IN'), ('alcohol', 'NN'), ('consumption', 'NN')]
# [('mild', 'NN'), ('fever', 'NN')]
# [('polyuria', 'NNS')]
# [('passage', 'NN'), ('of', 'IN'), ('gases', 'NNS')]
# [('excessive', 'JJ'), ('hunger', 'NN')]
# [('ulcers', 'NNS'), ('on', 'IN'), ('tongue', 'NN')]
# [('skin', 'NN'), ('rash', 'NN')]
# [('painful', 'JJ'), ('walking', 'NN')]
# [('nodal', 'JJ'), ('skin', 'NN'), ('eruptions', 'NNS')]
# [('chills', 'NNS')]
# [('blurred', 'VBN'), ('and', 'CC'), ('distorted', 'VBN'), ('vision', 'NN')]
# [('fatigue', 'NN')]
# [('mood', 'NN'), ('swings', 'NNS')]
# [('high', 'JJ'), ('fever', 'NN')]
# [('acidity', 'NN')]
# [('weight', 'NN'), ('loss', 'NN')]
# [('dischromic', 'JJ'), ('patches', 'NNS')]
# [('neck', 'NN'), ('pain', 'NN')]
# [('coma', 'NN')]
# [('red', 'JJ'), ('spots', 'NNS'), ('over', 'IN'), ('body', 'NN')]
# [('indigestion', 'NN')]
# [('throat', 'NN'), ('irritation', 'NN')]
# [('pain', 'NN'), ('in', 'IN'), ('anal', 'JJ'), ('region', 'NN')]
# [('swelling', 'VBG'), ('joints', 'NNS')]
# [('sunken', 'JJ'), ('eyes', 'NNS')]
# [('rusty', 'JJ'), ('sputum', 'NN')]
# [('swelling', 'VBG'), ('of', 'IN'), ('stomach', 'NN')]
# [('internal', 'JJ'), ('itching', 'NN')]
# [('distention', 'NN'), ('of', 'IN'), ('abdomen', 'NNS')]
# [('abdominal', 'JJ'), ('pain', 'NN')]
# [('continuous', 'JJ'), ('sneezing', 'VBG')]
# [('anxiety', 'NN')]
# [('palpitations', 'NNS')]
# [('fast', 'JJ'), ('heart', 'NN'), ('rate', 'NN')]
# [('diarrhoea', 'NN')]
# [('irregular', 'JJ'), ('sugar', 'NN'), ('level', 'NN')]
# [('visual', 'JJ'), ('disturbances', 'NNS')]
# [('unsteadiness', 'NN')]
# [('pus', 'NN'), ('filled', 'VBD'), ('pimples', 'NNS')]
# [('bruising', 'NN')]
# [('yellow', 'JJ'), ('urine', 'NN')]
# [('muscle', 'NN'), ('pain', 'NN')]
# [('receiving', 'VBG'), ('blood', 'NN'), ('transfusion', 'NN')]
# [('prominent', 'JJ'), ('veins', 'NNS'), ('on', 'IN'), ('calf', 'NN')]
# [('runny', 'NN'), ('nose', 'NN')]
# [('foul', 'NN'), ('smell', 'NN'), ('of', 'IN'), ('urine', 'NN')]
# [('red', 'JJ'), ('sore', 'NN'), ('around', 'IN'), ('nose', 'JJ')]
# [('blackheads', 'NNS')]
# [('extra', 'JJ'), ('marital', 'JJ'), ('contacts', 'NNS')]
# [('swollen', 'JJ'), ('extremeties', 'NNS')]
# [('stomach', 'NN'), ('pain', 'NN')]
# [('weakness', 'NN'), ('in', 'IN'), ('limbs', 'NNS')]
# [('vomiting', 'VBG')]
# [('yellowing', 'NN'), ('of', 'IN'), ('eyes', 'NNS')]
# [('family', 'NN'), ('history', 'NN')]
# [('movement', 'NN'), ('stiffness', 'NN')]
# [('restlessness', 'NN')]
# [('cramps', 'NNS')]
# [('muscle', 'NN'), ('weakness', 'NN')]
# [('drying', 'NN'), ('and', 'CC'), ('tingling', 'VBG'), ('lips', 'NNS')]
# [('swelled', 'VBN'), ('lymph', 'NN'), ('nodes', 'NNS')]
# [('back', 'RB'), ('pain', 'NN')]
# [('dark', 'JJ'), ('urine', 'NN')]
# [('toxic', 'JJ'), ('look', 'NN'), ('(', '('), ('typhos', 'NN'), (')', ')')]
# [('phlegm', 'NN')]
# [('pain', 'NN'), ('during', 'IN'), ('bowel', 'NN'), ('movements', 'NNS')]
# [('pain', 'NN'), ('behind', 'IN'), ('the', 'DT'), ('eyes', 'NNS')]
# [('dehydration', 'NN')]
# [('patches', 'NNS'), ('in', 'IN'), ('throat', 'NN')]
# [('loss', 'NN'), ('of', 'IN'), ('smell', 'NN')]
# [('burning', 'VBG'), ('micturition', 'NN')]
# [('fluid', 'NN'), ('overload', 'NN')]
# [('sinus', 'NN'), ('pressure', 'NN')]
# [('cold', 'JJ'), ('hands', 'NNS'), ('and', 'CC'), ('feets', 'NNS')]
# [('nausea', 'NN')]
# [('belly', 'RB'), ('pain', 'NN')]
# [('spinning', 'VBG'), ('movements', 'NNS')]
# [('watering', 'VBG'), ('from', 'IN'), ('eyes', 'NNS')]
# [('stomach', 'NN'), ('bleeding', 'NN')]
# [('bloody', 'NN'), ('stool', 'NN')]
# [('lack', 'NN'), ('of', 'IN'), ('concentration', 'NN')]
# [('bladder', 'NN'), ('discomfort', 'NN')]
# [('enlarged', 'VBN'), ('thyroid', 'NN')]
# [('constipation', 'NN')]
# [('blister', 'NN')]
# [('joint', 'NN'), ('pain', 'NN')]
# [('lethargy', 'NN')]
# [('irritability', 'NN')]
# [('spotting', 'VBG'), ('urination', 'NN')]
# [('mucoid', 'NN'), ('sputum', 'NN')]
# [('chest', 'NN'), ('pain', 'NN')]
# [('increased', 'VBN'), ('appetite', 'NN')]
