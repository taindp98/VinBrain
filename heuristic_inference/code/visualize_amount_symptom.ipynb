# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/home/taindp/VINBRAIN_INTERNSHIP/explore_kb/code'

# %%
_DATASET = '/home/taindp/VINBRAIN_INTERNSHIP/explore_kb/data/dataset.csv'

# %%
dataset = pd.read_csv(_DATASET)
dataset
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
dataset = dataset.fillna('none_symptom')

# %%
# dataset.head()

# %% [markdown]
# # GROUPBY

# %%
list_symptom_columns = list(dataset.columns)
list_symptom_columns
# Out:
# ['Disease',
#  'Symptom_1',
#  'Symptom_2',
#  'Symptom_3',
#  'Symptom_4',
#  'Symptom_5',
#  'Symptom_6',
#  'Symptom_7',
#  'Symptom_8',
#  'Symptom_9',
#  'Symptom_10',
#  'Symptom_11',
#  'Symptom_12',
#  'Symptom_13',
#  'Symptom_14',
#  'Symptom_15',
#  'Symptom_16',
#  'Symptom_17']

# %%
list_symptoms_unique = []
for col in list_symptom_columns:
    list_symptoms = list(dataset[col].unique())
    for item in list_symptoms:
        if item not in list_symptoms_unique:
            list_symptoms_unique.append(item)

# %%
len(list_symptoms_unique)
# Out:
# 173

# %%
list_symptoms_unique.index('none_symptom')
# Out:
# 114

# %% [markdown]
# # COUNT

# %%
dict_count = {}
for col in list_symptom_columns:
    if col != 'Disease':
        list_count_one_col = []

        list_symptoms = list(dataset[col])
        for item in list_symptoms_unique:
            
            if list_symptoms.count(item) != 0:
                zip_count_one_symptom = [list_symptoms.count(item),item]
                list_count_one_col.append(zip_count_one_symptom)
        zip_count_sort = sorted(list_count_one_col,reverse=False)
        dict_count[col] = zip_count_sort

# %%
def visualize_count_symptom(list_count,symptom):
    plt.figure(figsize=(10,10))
    plt.barh([item[1] for item in list_count],[item[0] for item in list_count])
    plt.ylabel(symptom)
    plt.xlabel('Quantity')
    plt.show()

# %%
for symp in list(dict_count.keys()):
    list_count = dict_count[symp]
    visualize_count_symptom(list_count,symp)
